# %%
import json
import re
import string
import spacy
from spacy.matcher import Matcher
from fuzzywuzzy import fuzz
import pandas as pd
from collections import Counter 

import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import stopwords

# Run the 1st time
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('stopwords')
# install python-Levenshtein

def get_tweet_data(year):
    # load tweet data
    file_string = 'gg' + str(year) + '.json'
    tweets = {}
    with open(file_string, 'r') as f:
        tweets = json.load(f)
    
    # extract 'text' field from tweets
    tweets = [tweet['text'] for tweet in tweets]
    # tweets = [tweet['text'] for tweet in tweets if 'best' in tweet['text'].lower()]
    
    # remove @,# tokens
    tweets = [remove_symbols(tweet) for tweet in tweets]
    
    return tweets

def remove_symbols(a_tweet):
#     entity_prefixes = ['@','#','(',')']
    entity_prefixes = ['#','(',')']
    words = []
    for word in a_tweet.split():
        word = word.strip()
        if word and word.lower() != 'rt':
            if word[0].lower() not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

def get_NNP(tweets_list):
    NNP_dict = {}
    for tweet in tweets_list:
        tokens = nltk.word_tokenize(tweet)
        tags = nltk.pos_tag(tokens)
        for word in tags:
            if word[1] in ['NNP']:
                name = word[0].lower()
                if name in NNP_dict:
                    NNP_dict[name] += 1
                else:
                    NNP_dict[name] = 1
    return NNP_dict

def get_top_percent(dictionary, percentile):
    if dictionary == {}:
        return []
    max_val = max(dictionary.values())
    threshold = max_val * percentile
    result = []
    for key in dictionary:
        if dictionary[key] > threshold:
            result.append(key)
    return result

def remove_category_tokens(category, pronouns_dict):
    tokens = nltk.word_tokenize(category)
    tokens += ['motion picture', 'golden', 'globe', 'television series', 'tv series', 'mini-', 'rt','⁰']
    
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words] 
    
    deletes = []
    for token in tokens:
        for key in pronouns_dict:
            if token in key:
                deletes.append(key)
    deletes = list(set(deletes)) 
    for key in deletes:
        del pronouns_dict[key]
    return pronouns_dict



def get_person_names(list_of_tweets, nlp):
    '''
    Input: a list of strings
    Returns: a dictionary where keys = actor/actress names, values = number of times the key is references in the list of tweets
    '''
    names_dictionary = {}
    for tweet in list_of_tweets:
        name = extract_full_name(nlp(tweet), nlp)
        if name:
            name = name.lower()
            if name in names_dictionary:
                names_dictionary[name] += 1
            else:
                names_dictionary[name] = 1
    return names_dictionary
    
    
def extract_full_name(nlp_doc, nlp):
    matcher = Matcher(nlp.vocab)
    pattern = [{'POS': 'PROPN'}, {'POS': 'PROPN'}]
    matcher.add('FULL_NAME', None, pattern)
    matches = matcher(nlp_doc)
    names = []
    for match_id, start, end in matches:
        span = nlp_doc[start:end]
        names.append(span.text)
    return names
    
def extract_one_name(nlp_doc, nlp):
    matcher = Matcher(nlp.vocab)
    pattern = [{'POS': 'PROPN'}]
    matcher.add('FULL_NAME', None, pattern)
    matches = matcher(nlp_doc)
    names = []
    for match_id, start, end in matches:
        span = nlp_doc[start:end]
        names.append(span.text)
    return names
    
def get_person(tweet):
    words = [(ent.text, ent.label_) for ent in tweet.ents]
    return ([token[0] for token in list(filter(lambda x: "PERSON" in x, words))])

def test_trans(s):
    table = str.maketrans('', '', string.punctuation)
    return s.translate(table)

def remove_stopwords(text):
    stop_words = stopwords.words('english')
    stop_words.append('performance')
    stop_words.append('television')
    stop_words.append('motion')
    stop_words.append('picture')
#     stop_words.append('series')
    stopwords_dict = Counter(stop_words)

    text = ' '.join([word for word in text.split() if word not in stopwords_dict])
    return text

# %%
# print(get_person(nlp('George hope Argo wins best Harold director Frank Lee')))
s = 'George hope Argo wins best Harold director Frank Lee'
# s = 'Best motion picture drama goes to Django Unchained'
# s = 'Jim Wins Best Motion Picture Drama!'
s = 'ColumbiaRecords Tune in now to watch the OfficialAdele and PaulEpworth have been nominated for Best Song for'
s = 'Argo Really It was a great film but Lincoln should have won Best picture'


print(extract_full_name(nlp(s),nlp))
print(extract_one_name(nlp(s),nlp))
print(get_person(nlp(s)))
print(get_NNP([s]))
# Out:
# []
# ['Lincoln']
# []
# {'argo': 1, 'really': 1, 'lincoln': 1, 'best': 1}

# %%
year = 2013
tweets = get_tweet_data(year)

OFFICIAL_AWARDS_1315 = ['cecil b. demille award', 'best motion picture - drama', 'best performance by an actress in a motion picture - drama', 'best performance by an actor in a motion picture - drama', 'best motion picture - comedy or musical', 'best performance by an actress in a motion picture - comedy or musical', 'best performance by an actor in a motion picture - comedy or musical', 'best animated feature film', 'best foreign language film', 'best performance by an actress in a supporting role in a motion picture', 'best performance by an actor in a supporting role in a motion picture', 'best director - motion picture', 'best screenplay - motion picture', 'best original score - motion picture', 'best original song - motion picture', 'best television series - drama', 'best performance by an actress in a television series - drama', 'best performance by an actor in a television series - drama', 'best television series - comedy or musical', 'best performance by an actress in a television series - comedy or musical', 'best performance by an actor in a television series - comedy or musical', 'best mini-series or motion picture made for television', 'best performance by an actress in a mini-series or motion picture made for television', 'best performance by an actor in a mini-series or motion picture made for television', 'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television', 'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television']
OFFICIAL_AWARDS_1315_tv = [x for x in OFFICIAL_AWARDS_1315 if 'television' in x]
d = {}
for a in OFFICIAL_AWARDS_1315:
    d[a] = {}

keywords_lst = [['win', 'hope', ' best '], ['nominated for', ' best '], ['should have won', ' best ']]
nlp = spacy.load('en_core_web_sm')

for keywords in keywords_lst:
    # keywords = 
    # keywords = ['should have won', ' best ']
    # keywords = ['didn\'t win', 'best']
    # keywords = ['best actress']

    count = 0
    trys = []
    for t in tweets:
        if all(x in t.lower() for x in keywords) and 'dress' not in t.lower():
            trys.append(t)
            count += 1
    print(count)
    # print(trys)


    for t1 in trys:
        t1 = test_trans(t1)
        names = extract_full_name(nlp(t1), nlp)
        if names == []:
            names = extract_one_name(nlp(t1), nlp)
            if names == []:
#                 print('No double or single names')
#                 print()
                continue
#         print(t1)

        t2 = t1.lower().split()


        award = []
        start = t2.index('best')
        end_words = ['award', 'drama', 'comedy', 'musical', 'film', 'director', 'series']
        for i in range(start, len(t2)):
            if t2[i] in end_words:
                award.append(t2[i])
                break
            if i - start >= 6:
                break
            award.append(t2[i])

        s = ''
        for x in award:
            s = s + x + ' '
        award = s

#         print('Name:', names, '||| Award:', award)

        best_score = 0
        best_category = None
        
        if 'tv' in award:
            all_awards = OFFICIAL_AWARDS_1315_tv
        else:
            all_awards = OFFICIAL_AWARDS_1315
        
        for a in all_awards:
            search_award = remove_stopwords(a)
            if 'television' in a:
                search_award += ' tv'

            score = fuzz.partial_ratio(search_award, award)
            if score > best_score:
                best_score = score
                best_category = a
#         print('Score:', best_score, '||| Category:', best_category)

        if best_category == None:
#             print()
            continue

        if names:
            for name in names:
                if name.lower() in d[best_category]:
                    d[best_category][name.lower()] += 1
                else:
                    d[best_category][name.lower()] = 1
#         print()

for key in d:
    d[key] = remove_category_tokens(key, d[key])

nominees_dict = {}
for key in d:
    k = Counter(d[key]) 
    high = k.most_common(4) 
    nominees_dict[key] = [x[0] for x in high]
    while len(nominees_dict[key]) < 4:
        nominees_dict[key].append('L')
print(nominees_dict)
# Out:
# 22
# 89
# 20
# {'cecil b. demille award': ['L', 'L', 'L', 'L'], 'best motion picture - drama': ['mad men', 'theweek reminder', 'life', 'pi'], 'best performance by an actress in a motion picture - drama': ['kim kardashian', 'lokipage times', 'rachel weisz', 'deep blue'], 'best performance by an actor in a motion picture - drama': ['amanda seyfried', 'mean girls', 'hugh jackmans', 'realhughjackman congrats'], 'best motion picture - comedy or musical': ['les mis', 'silver linings', 'linings playbook', 'L'], 'best performance by an actress in a motion picture - comedy or musical': ['jennifer lawrence', 'L', 'L', 'L'], 'best performance by an actor in a motion picture - comedy or musical': ['matt leblanc', 'L', 'L', 'L'], 'best animated feature film': ['sweetdurga paranorman', 'wreck', 'L', 'L'], 'best foreign language film': ['oskrnyc', 'cajas', 'L', 'L'], 'best performance by an actress in a supporting role in a motion picture': ['end roll', 'L', 'L', 'L'], 'best performance by an actor in a supporting role in a motion picture': ['selena gomez', 'anne hathaways', 'hathaways freshfaced', 'freshfaced beauty'], 'best director - motion picture': ['ben affleck', 'catherine zeta', 'zeta jones', 'tmobile commercial'], 'best screenplay - motion picture': ['L', 'L', 'L', 'L'], 'best original score - motion picture': ['lesmiserables', 'les miserables', '☹ lets', 'jgarrow123 safe'], 'best original song - motion picture': ['keith urban', 'black coffins', 'taylor swift', 'civil wars'], 'best television series - drama': ['marqueemarc', 'm', 'ericrosenblatt', 'the wire'], 'best performance by an actress in a television series - drama': ['L', 'L', 'L', 'L'], 'best performance by an actor in a television series - drama': ['president clinton', 'L', 'L', 'L'], 'best television series - comedy or musical': ['L', 'L', 'L', 'L'], 'best performance by an actress in a television series - comedy or musical': ['L', 'L', 'L', 'L'], 'best performance by an actor in a television series - comedy or musical': ['L', 'L', 'L', 'L'], 'best mini-series or motion picture made for television': ['exotic marigold', 'marigold hotel', 'hour', 'life'], 'best performance by an actress in a mini-series or motion picture made for television': ['lena dunham', 'series comedymusical', 'L', 'L'], 'best performance by an actor in a mini-series or motion picture made for television': ['damian fransisco', 'dog president', 'tina fey', 'fey damian'], 'best performance by an actress in a supporting role in a series, mini-series or motion picture made for television': ['L', 'L', 'L', 'L'], 'best performance by an actor in a supporting role in a series, mini-series or motion picture made for television': ['toby jones', 'L', 'L', 'L']}

# %%
keywords = ['didn\'t win', 'best']

count = 0
trys = []
for t in tweets:
    if all(x in t.lower() for x in keywords) and 'dress' not in t.lower():
        trys.append(t)
        count += 1
print(count)
    
for t1 in trys:
    t1 = test_trans(t1)
    names = extract_full_name(nlp(t1), nlp)
    if names == []:
        names = extract_one_name(nlp(t1), nlp)
        if names == []:
            print('No double or single names')
            print()
            continue
    print(t1)
    
    t2 = t1.lower().split()
    
    
    award = []
    start = t2.index('best')
    end_words = ['award', 'drama', 'comedy', 'musical', 'film', 'director', 'series']
    for i in range(start, len(t2)):
        if t2[i] in end_words:
            award.append(t2[i])
            break
        if i - start >= 6:
            break
        award.append(t2[i])

    s = ''
    for x in award:
        s = s + x + ' '
    award = s

    print('Name:', names, '||| Award:', award)
    
    best_score = 0
    best_category = None
    if 'tv' in award:
        all_awards = OFFICIAL_AWARDS_1315_tv
    else:
        all_awards = OFFICIAL_AWARDS_1315
    for a in all_awards:
        search_award = remove_stopwords(a)
        if 'television' in a:
            search_award += ' tv'

        score = fuzz.partial_ratio(search_award, award)
        if score > best_score:
            best_score = score
            best_category = a
    print('Score:', best_score, '||| Category:', best_category)
    
    if best_category == None:
        print()
        continue
    
    if names:
        for name in names:
            if name.lower() in d[best_category]:
                d[best_category][name.lower()] += 1
            else:
                d[best_category][name.lower()] = 1
    print()
# Out:
# 28
# There should be an award for Best Host If Tina Fey Amy Poehler didnt win Id scream bloody murder
# Name: ['Tina Fey', 'Fey Amy', 'Amy Poehler'] ||| Award: best host if tina fey amy
# Score: 57 ||| Category: best original score - motion picture
#
# Well clearly the woman with the best didnt win Too bad SofiaVergara but I think youre fabulous on
# Name: ['SofiaVergara'] ||| Award: best didnt win too bad sofiavergara
# Score: 60 ||| Category: best director - motion picture
#
# Cant believe the Hatfields amp McCoys didnt win for Best Mini Series
# Name: ['Best Mini'] ||| Award: best mini series
# Score: 94 ||| Category: best mini-series or motion picture made for television
#
# Pissed Jessica Lange didnt win best actress And why was American horror story not nominated for best miniseries
# Name: ['Jessica Lange'] ||| Award: best actress and why was american
# Score: 70 ||| Category: best performance by an actress in a motion picture - drama
#
# The best Sarah Palin is at the but she didnt win the award
# Name: ['Sarah Palin'] ||| Award: best sarah palin is at the
# Score: 59 ||| Category: best screenplay - motion picture
#
# No double or single names
#
# MTLDriveFor25 And Breaking Bad didnt win best TV series either
# Name: ['Breaking Bad'] ||| Award: best tv series
# Score: 80 ||| Category: best television series - drama
#
# MTLDriveFor25 Bryan Cranston seriously didnt win best actor in a TV series Wow
# Name: ['MTLDriveFor25 Bryan', 'Bryan Cranston'] ||| Award: best actor in a tv series
# Score: 77 ||| Category: best performance by an actor in a mini-series or motion picture made for television
#
# RandyHollywood Just legitimately got mad that Breaking Bad didnt win best drama on the Golden Globes
# Name: ['Golden Globes'] ||| Award: best drama
# Score: 82 ||| Category: best motion picture - drama
#
# Breaking bad was nominated for best tv show drama at the golden globes but didnt win alexarosenblum EricRosenblatt joshminzer
# Name: ['globes', 'EricRosenblatt'] ||| Award: best tv show drama
# Score: 63 ||| Category: best television series - drama
#
# The real reason why I dont watch the Golden Globes is because Im still pissed that Bey didnt win for Best Actress Fuck the Globes
# Name: ['Golden Globes'] ||| Award: best actress fuck the globes
# Score: 70 ||| Category: best performance by an actress in a motion picture - drama
#
# taylorswift13 I see youre really pissed you didnt win the best original song on golden globes
# Name: ['taylorswift13', 'globes'] ||| Award: best original song on golden globes
# Score: 95 ||| Category: best original song - motion picture
#
# goldenglobes Taylor looked a little miffed that she didnt win Best Original Song Adele
# Name: ['goldenglobes Taylor'] ||| Award: best original song adele
# Score: 95 ||| Category: best original song - motion picture
#
# DragonsKitchen Taylor Swift looked pissed that she didnt win best songoh no Golden Globes shes gonna write a bitter song about you
# Name: ['DragonsKitchen Taylor', 'Taylor Swift', 'Golden Globes'] ||| Award: best songoh no golden globes shes
# Score: 52 ||| Category: best original score - motion picture
#
# People are mad because sky fall won Yeh les mis didnt win best original song but hey ho its Adele
# Name: ['Yeh les', 'les mis'] ||| Award: best original song but hey ho
# Score: 95 ||| Category: best original song - motion picture
#
# But Taylor didnt win Best Original Song for Motion Picture Oh well congrats Adele for the win
# Name: ['Motion Picture'] ||| Award: best original song for motion picture
# Score: 95 ||| Category: best original song - motion picture
#
# toddbarry sucks you didnt win Best Reoccurring Character by a Stand Up Comedian in a TV Series  Comedy or Musical for Louie
# Name: ['Comedy', 'Musical', 'Louie'] ||| Award: best reoccurring character by a stand
# Score: 60 ||| Category: best director - motion picture
#
# the best thing about the golden globes is seeing sherlock fans lose their shit because bandicoot candyflaps didnt win
# Name: ['globes'] ||| Award: best thing about the golden globes
# Score: 58 ||| Category: best motion picture - drama
#
# Soooooooooooooo disappointed that didnt win Its the best show on television
# Name: ['Soooooooooooooo'] ||| Award: best show on television
# Score: 50 ||| Category: best motion picture - drama
#
# you mean to tell me THE DICTATOR didnt win Best Picture of the Year
# Name: ['DICTATOR'] ||| Award: best picture of the year
# Score: 67 ||| Category: best director - motion picture
#
# wins Best Picture So glad Lincoln didnt win
# Name: ['Lincoln'] ||| Award: best picture so glad lincoln didnt
# Score: 67 ||| Category: best director - motion picture
#
# Argo for Best Picture Well deserved Glad Lincoln didnt win
# Name: ['Glad Lincoln'] ||| Award: best picture well deserved glad lincoln
# Score: 67 ||| Category: best director - motion picture
#
# CALL THE AUTHORITIES THE GOLDEN GLOBES HAVE COMMITTED A CRIME DJANGO UNCHAINED DIDNT WIN BEST MOTION PICTURE
# Name: ['GOLDEN GLOBES'] ||| Award: best motion picture
# Score: 65 ||| Category: best original score - motion picture
#
#  and they went over time Congrats to Argo for best drama Im just glad the vastly overrated Lincoln didnt win
# Name: ['Lincoln'] ||| Award: best drama
# Score: 82 ||| Category: best motion picture - drama
#
# Im still upset that JudahWorldChamp didnt win Best supporting actor for Wet Hot American Summer
# Name: ['Wet Hot', 'Hot American', 'American Summer'] ||| Award: best supporting actor for wet hot
# Score: 69 ||| Category: best performance by an actor in a supporting role in a motion picture
#
# Im super bummed that the Seahawks didnt win a for best drama
# Name: ['Seahawks'] ||| Award: best drama
# Score: 82 ||| Category: best motion picture - drama
#
# What Magic Mike didnt win best picture
# Name: ['Magic Mike'] ||| Award: best picture
# Score: 77 ||| Category: best performance by an actress in a motion picture - drama
#
# imandyhaynes Im super bummed that the Seahawks didnt win a for best drama
# Name: ['Seahawks'] ||| Award: best drama
# Score: 82 ||| Category: best motion picture - drama

# %%
a = 'best tv series'
b = remove_stopwords('best performance by an actress in a motion picture - drama')
c = remove_stopwords('best television series drama') + ' tv'

a,b,c = 'lana del', 'del rey', 'lanapedia lana'


print(a, '\n', b, '\n', c)

r1 = fuzz.token_sort_ratio(a, b)
print(r1)
r2 = fuzz.token_sort_ratio(a, c)
print(r2)

print()
r1 = fuzz.partial_ratio(a, b)
print(r1)
r2 = fuzz.partial_ratio(a, c)
print(r2)

print()
r1 = fuzz.ratio(a, b)
print(r1)
r2 = fuzz.ratio(a, c)
print(r2)
# Out:
# lana del
#  del rey
#  boogie woogie
# 53
# 19
#
# 43
# 25
#
# 40
# 19
